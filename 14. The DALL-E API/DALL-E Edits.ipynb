# %%
import openai

# %%
from dotenv import dotenv_values

# %%
config = dotenv_values(".env")

# %%
openai.api_key = config["OPENAI_API_KEY"]

# %%
from IPython.core.display import Image

# %%
wave_image = open("./images/great_wave.png", "rb").read()

# %%
Image(data=wave_image, width=256)

# %%
wave_image_mask = open("./images/great_wave_mask.png", "rb").read()

# %%
Image(data=wave_image_mask, width=256)

# %%
response = openai.Image.create_edit(
    image=wave_image,
    mask=wave_image_mask,
    prompt="a surfer riding a surfboard down the Great Wave",
    n=1,
    size="1024x1024"
)

# %%
Image(url=response["data"][0]["url"])
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-8VssGxYvz9qROZ6SXoA1q3re/user-osJi3DC7MRAwMAt8LmCHH2q4/img-bZT2C38IIbP6fJF6yhe0bDHO.png?st=2023-03-28T02%3A41%3A34Z&se=2023-03-28T04%3A41%3A34Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-27T20%3A35%3A06Z&ske=2023-03-28T20%3A35%3A06Z&sks=b&skv=2021-08-06&sig=hfEQcjJG8bL%2B88XcIi1vwviipQX/qjTTTnVXX/lezis%3D"/>
